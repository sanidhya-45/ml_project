# %%
# import numpy as np
# from sklearn.model_selection import KFold
# import tensorflow as tf

# # Load the Fashion-MNIST dataset
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# # Preprocess the data
# x_train = x_train / 255.0
# x_test = x_test / 255.0
# x_train = x_train[..., np.newaxis]
# x_test = x_test[..., np.newaxis]

# # Combine the train and test sets for cross-validation
# x = np.concatenate((x_train, x_test), axis=0)
# y = np.concatenate((y_train, y_test), axis=0)

# # Number of folds
# n_folds = 5

# # Define the CNN model
# def create_cnn_model():
#     model = tf.keras.Sequential([
#         tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
#         tf.keras.layers.MaxPooling2D((2, 2)),
#         tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
#         tf.keras.layers.MaxPooling2D((2, 2)),
#         tf.keras.layers.Flatten(),
#         tf.keras.layers.Dense(128, activation='relu'),
#         tf.keras.layers.Dense(10, activation='softmax')
#     ])
#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return model

# # Perform k-fold cross-validation
# kf = KFold(n_splits=n_folds)
# fold_accuracies = []

# for train_index, val_index in kf.split(x):
#     x_train_fold, x_val_fold = x[train_index], x[val_index]
#     y_train_fold, y_val_fold = y[train_index], y[val_index]

#     cnn_model = create_cnn_model()
#     cnn_model.fit(x_train_fold, y_train_fold, epochs=10, batch_size=128, verbose=0)

#     val_loss, val_accuracy = cnn_model.evaluate(x_val_fold, y_val_fold, verbose=0)
#     fold_accuracies.append(val_accuracy)

# # Print the average accuracy across all folds
# print("Average accuracy: {:.2f}%".format(np.mean(fold_accuracies)*100))
# Out:
# Average accuracy: 91.45%

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report
# from keras.datasets import fashion_mnist
# from keras.utils import to_categorical
# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# # Load the Fashion MNIST dataset
# (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# # Perform data preprocessing
# X_train = X_train.reshape(-1, 28, 28, 1) / 255.0
# X_test = X_test.reshape(-1, 28, 28, 1) / 255.0
# y_train = to_categorical(y_train, 10)
# y_test = to_categorical(y_test, 10)

# # Split the data into training and validation sets
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# # Define the CNN model
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 1)))
# model.add(MaxPooling2D((2, 2)))
# model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation='softmax'))

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# # Train the model
# history = model.fit(X_train, y_train, batch_size=128, epochs=10, validation_data=(X_val, y_val))

# # Evaluate the model on the test set
# scores = model.evaluate(X_test, y_test, verbose=0)
# print('Test loss:', scores[0])
# print('Test accuracy:', scores[1])

# # Plot accuracy and loss graphs
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='upper right')
# plt.show()

# # Generate classification report
# y_pred = model.predict(X_test)
# y_pred_classes = np.argmax(y_pred, axis=1)
# y_true_classes = np.argmax(y_test, axis=1)
# target_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#                 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# print('Classification Report:')
# print(classification_report(y_true_classes, y_pred_classes, target_names=target_names))
# Out:
# Epoch 1/10
# 375/375 [==============================] - 30s 77ms/step - loss: 0.6387 - accuracy: 0.7688 - val_loss: 0.3683 - val_accuracy: 0.8712
# Epoch 2/10
# 375/375 [==============================] - 33s 89ms/step - loss: 0.4009 - accuracy: 0.8562 - val_loss: 0.3190 - val_accuracy: 0.8816
# Epoch 3/10
# 375/375 [==============================] - 33s 88ms/step - loss: 0.3483 - accuracy: 0.8761 - val_loss: 0.2868 - val_accuracy: 0.8935
# Epoch 4/10
# 375/375 [==============================] - 31s 83ms/step - loss: 0.3138 - accuracy: 0.8855 - val_loss: 0.2632 - val_accuracy: 0.9040
# Epoch 5/10
# 375/375 [==============================] - 31s 83ms/step - loss: 0.2879 - accuracy: 0.8954 - val_loss: 0.2534 - val_accuracy: 0.9048
# Epoch 6/10
# 375/375 [==============================] - 33s 87ms/step - loss: 0.2669 - accuracy: 0.9025 - val_loss: 0.2423 - val_accuracy: 0.9085
# Epoch 7/10
# 375/375 [==============================] - 31s 83ms/step - loss: 0.2512 - accuracy: 0.9082 - val_loss: 0.2321 - val_accuracy: 0.9127
# Epoch 8/10
# 375/375 [==============================] - 34s 91ms/step - loss: 0.2354 - accuracy: 0.9135 - val_loss: 0.2232 - val_accuracy: 0.9170
# Epoch 9/10
# 375/375 [==============================] - 33s 87ms/step - loss: 0.2243 - accuracy: 0.9171 - val_loss: 0.2476 - val_accuracy: 0.9068
# Epoch 10/10
# 375/375 [==============================] - 31s 83ms/step - loss: 0.2138 - accuracy: 0.9217 - val_loss: 0.2200 - val_accuracy: 0.9162
# Test loss: 0.24106615781784058
# Test accuracy: 0.9114999771118164
# 313/313 [==============================] - 2s 6ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.88      0.85      0.87      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.89      0.82      0.85      1000
#        Dress       0.91      0.90      0.91      1000
#         Coat       0.80      0.90      0.85      1000
#       Sandal       0.98      0.99      0.99      1000
#        Shirt       0.74      0.76      0.75      1000
#      Sneaker       0.97      0.96      0.97      1000
#          Bag       0.99      0.98      0.99      1000
#   Ankle boot       0.97      0.97      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import classification_report
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Load the Fashion MNIST dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Perform data preprocessing
X_train = X_train.reshape(-1, 28, 28, 1) / 255.0
X_test = X_test.reshape(-1, 28, 28, 1) / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Perform K-fold cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)
fold_acc = []

for i, (train_index, val_index) in enumerate(kf.split(X_train, y_train)):
    print('Training on fold {}/{}'.format(i + 1, num_folds))
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Train the model on the current fold
    history = model.fit(X_train_fold, y_train_fold, batch_size=128, epochs=10, validation_data=(X_val_fold, y_val_fold))

    # Evaluate the model on the current fold
    scores = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    fold_acc.append(scores[1])

# Calculate and print average cross-validation accuracy
avg_acc = np.mean(fold_acc)
print('Average cross-validation accuracy: {:.4f}'.format(avg_acc))

# Train the model on the entire training set
model.fit(X_train, y_train, batch_size=128, epochs=10, validation_data=(X_val, y_val))

# Evaluate the model on the test set
scores = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# Plot accuracy and loss graphs
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Training on fold 1/5
# Epoch 1/10
# 300/300 [==============================] - 24s 74ms/step - loss: 0.6783 - accuracy: 0.7552 - val_loss: 0.3916 - val_accuracy: 0.8617
# Epoch 2/10
# 300/300 [==============================] - 25s 83ms/step - loss: 0.4267 - accuracy: 0.8490 - val_loss: 0.3218 - val_accuracy: 0.8858
# Epoch 3/10
# 300/300 [==============================] - 25s 84ms/step - loss: 0.3689 - accuracy: 0.8688 - val_loss: 0.3112 - val_accuracy: 0.8864
# Epoch 4/10
# 300/300 [==============================] - 27s 91ms/step - loss: 0.3340 - accuracy: 0.8815 - val_loss: 0.2760 - val_accuracy: 0.8995
# Epoch 5/10
# 300/300 [==============================] - 25s 85ms/step - loss: 0.3063 - accuracy: 0.8893 - val_loss: 0.2557 - val_accuracy: 0.9049
# Epoch 6/10
# 300/300 [==============================] - 24s 78ms/step - loss: 0.2885 - accuracy: 0.8960 - val_loss: 0.2421 - val_accuracy: 0.9116
# Epoch 7/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.2664 - accuracy: 0.9036 - val_loss: 0.2382 - val_accuracy: 0.9097
# Epoch 8/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.2529 - accuracy: 0.9089 - val_loss: 0.2282 - val_accuracy: 0.9146
# Epoch 9/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.2379 - accuracy: 0.9140 - val_loss: 0.2271 - val_accuracy: 0.9166
# Epoch 10/10
# 300/300 [==============================] - 23s 77ms/step - loss: 0.2283 - accuracy: 0.9161 - val_loss: 0.2441 - val_accuracy: 0.9094
# Training on fold 2/5
# Epoch 1/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.2282 - accuracy: 0.9181 - val_loss: 0.1722 - val_accuracy: 0.9336
# Epoch 2/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.2124 - accuracy: 0.9241 - val_loss: 0.1806 - val_accuracy: 0.9298
# Epoch 3/10
# 300/300 [==============================] - 22s 75ms/step - loss: 0.2020 - accuracy: 0.9266 - val_loss: 0.1714 - val_accuracy: 0.9349
# Epoch 4/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.1906 - accuracy: 0.9301 - val_loss: 0.1744 - val_accuracy: 0.9357
# Epoch 5/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1788 - accuracy: 0.9333 - val_loss: 0.1707 - val_accuracy: 0.9359
# Epoch 6/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1684 - accuracy: 0.9379 - val_loss: 0.1695 - val_accuracy: 0.9375
# Epoch 7/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.1601 - accuracy: 0.9400 - val_loss: 0.1728 - val_accuracy: 0.9361
# Epoch 8/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1524 - accuracy: 0.9425 - val_loss: 0.1762 - val_accuracy: 0.9348
# Epoch 9/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1455 - accuracy: 0.9473 - val_loss: 0.1876 - val_accuracy: 0.9326
# Epoch 10/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.1354 - accuracy: 0.9479 - val_loss: 0.1834 - val_accuracy: 0.9355
# Training on fold 3/5
# Epoch 1/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.1580 - accuracy: 0.9418 - val_loss: 0.1082 - val_accuracy: 0.9613
# Epoch 2/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1459 - accuracy: 0.9470 - val_loss: 0.1030 - val_accuracy: 0.9627
# Epoch 3/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.1026 - val_accuracy: 0.9601
# Epoch 4/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1255 - accuracy: 0.9528 - val_loss: 0.1054 - val_accuracy: 0.9624
# Epoch 5/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.1191 - accuracy: 0.9558 - val_loss: 0.1068 - val_accuracy: 0.9609
# Epoch 6/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.1116 - accuracy: 0.9576 - val_loss: 0.1120 - val_accuracy: 0.9582
# Epoch 7/10
# 300/300 [==============================] - 23s 77ms/step - loss: 0.1046 - accuracy: 0.9593 - val_loss: 0.1123 - val_accuracy: 0.9592
# Epoch 8/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1009 - accuracy: 0.9618 - val_loss: 0.1193 - val_accuracy: 0.9570
# Epoch 9/10
# 300/300 [==============================] - 23s 77ms/step - loss: 0.0947 - accuracy: 0.9640 - val_loss: 0.1249 - val_accuracy: 0.9554
# Epoch 10/10
# 300/300 [==============================] - 25s 83ms/step - loss: 0.0902 - accuracy: 0.9659 - val_loss: 0.1289 - val_accuracy: 0.9536
# Training on fold 4/5
# Epoch 1/10
# 300/300 [==============================] - 24s 82ms/step - loss: 0.1148 - accuracy: 0.9574 - val_loss: 0.0550 - val_accuracy: 0.9823
# Epoch 2/10
# 300/300 [==============================] - 23s 76ms/step - loss: 0.1038 - accuracy: 0.9629 - val_loss: 0.0563 - val_accuracy: 0.9790
# Epoch 3/10
# 300/300 [==============================] - 23s 77ms/step - loss: 0.0944 - accuracy: 0.9641 - val_loss: 0.0617 - val_accuracy: 0.9786
# Epoch 4/10
# 300/300 [==============================] - 23s 77ms/step - loss: 0.0894 - accuracy: 0.9658 - val_loss: 0.0615 - val_accuracy: 0.9783
# Epoch 5/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0831 - accuracy: 0.9684 - val_loss: 0.0643 - val_accuracy: 0.9757
# Epoch 6/10
# 300/300 [==============================] - 22s 75ms/step - loss: 0.0838 - accuracy: 0.9680 - val_loss: 0.0736 - val_accuracy: 0.9720
# Epoch 7/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0778 - accuracy: 0.9693 - val_loss: 0.0664 - val_accuracy: 0.9751
# Epoch 8/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0751 - accuracy: 0.9711 - val_loss: 0.0721 - val_accuracy: 0.9748
# Epoch 9/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0660 - accuracy: 0.9740 - val_loss: 0.0758 - val_accuracy: 0.9730
# Epoch 10/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0654 - accuracy: 0.9745 - val_loss: 0.0872 - val_accuracy: 0.9684
# Training on fold 5/5
# Epoch 1/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0825 - accuracy: 0.9689 - val_loss: 0.0242 - val_accuracy: 0.9917
# Epoch 2/10
# 300/300 [==============================] - 22s 73ms/step - loss: 0.0755 - accuracy: 0.9715 - val_loss: 0.0284 - val_accuracy: 0.9909
# Epoch 3/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0750 - accuracy: 0.9701 - val_loss: 0.0365 - val_accuracy: 0.9873
# Epoch 4/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0703 - accuracy: 0.9718 - val_loss: 0.0348 - val_accuracy: 0.9877
# Epoch 5/10
# 300/300 [==============================] - 23s 75ms/step - loss: 0.0660 - accuracy: 0.9745 - val_loss: 0.0345 - val_accuracy: 0.9856
# Epoch 6/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0605 - accuracy: 0.9765 - val_loss: 0.0354 - val_accuracy: 0.9868
# Epoch 7/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0627 - accuracy: 0.9746 - val_loss: 0.0408 - val_accuracy: 0.9841
# Epoch 8/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0582 - accuracy: 0.9774 - val_loss: 0.0383 - val_accuracy: 0.9860
# Epoch 9/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0560 - accuracy: 0.9781 - val_loss: 0.0434 - val_accuracy: 0.9846
# Epoch 10/10
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0565 - accuracy: 0.9779 - val_loss: 0.0415 - val_accuracy: 0.9846
# Average cross-validation accuracy: 0.9503
# Epoch 1/10
# 375/375 [==============================] - 28s 74ms/step - loss: 0.0611 - accuracy: 0.9763 - val_loss: 0.3296 - val_accuracy: 0.9278
# Epoch 2/10
# 375/375 [==============================] - 28s 75ms/step - loss: 0.0585 - accuracy: 0.9776 - val_loss: 0.3136 - val_accuracy: 0.9283
# Epoch 3/10
# 375/375 [==============================] - 28s 74ms/step - loss: 0.0565 - accuracy: 0.9786 - val_loss: 0.3418 - val_accuracy: 0.9276
# Epoch 4/10
# 375/375 [==============================] - 28s 73ms/step - loss: 0.0531 - accuracy: 0.9791 - val_loss: 0.3200 - val_accuracy: 0.9287
# Epoch 5/10
# 375/375 [==============================] - 28s 75ms/step - loss: 0.0535 - accuracy: 0.9794 - val_loss: 0.3340 - val_accuracy: 0.9268
# Epoch 6/10
# 375/375 [==============================] - 27s 73ms/step - loss: 0.0538 - accuracy: 0.9781 - val_loss: 0.3483 - val_accuracy: 0.9277
# Epoch 7/10
# 375/375 [==============================] - 28s 74ms/step - loss: 0.0484 - accuracy: 0.9806 - val_loss: 0.3532 - val_accuracy: 0.9295
# Epoch 8/10
# 375/375 [==============================] - 28s 74ms/step - loss: 0.0498 - accuracy: 0.9804 - val_loss: 0.3614 - val_accuracy: 0.9255
# Epoch 9/10
# 375/375 [==============================] - 27s 73ms/step - loss: 0.0486 - accuracy: 0.9807 - val_loss: 0.3690 - val_accuracy: 0.9277
# Epoch 10/10
# 375/375 [==============================] - 28s 73ms/step - loss: 0.0506 - accuracy: 0.9800 - val_loss: 0.3774 - val_accuracy: 0.9279
# Test loss: 0.4522484838962555
# Test accuracy: 0.920799970626831
